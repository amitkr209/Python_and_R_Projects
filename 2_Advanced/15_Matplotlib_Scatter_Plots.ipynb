# %%
# Importing Library
from datasets import load_dataset
import ast
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Loading dataset
dataset = load_dataset("lukebarousse/data_jobs")
df = dataset['train'].to_pandas()

# Dataset Cleaning
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
data = {
    'job_skills' : ['python', 'sql', 'java', 'c++', 'c#', 'javascript', 'html', 'css', 'php', 'ruby'],
    'skill_count' : [30, 25, 20, 15, 10, 5, 4, 3, 2, 1],
    'skill_play' : [100, 90, 80, 70, 60, 50, 40, 30, 20, 10]
}

df_demo = pd.DataFrame(data)

# %%
# Plotting the scatter plot
df_demo.plot(kind='scatter', x='skill_count', y='skill_play')
plt.show()

# %%
df = df[df['job_title_short'] == 'Data Analyst']

df.head()
# Out:
#    job_title_short                                          job_title  \
# 1     Data Analyst                                       Data Analyst
# 12    Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18    Data Analyst                                       Data Analyst
# 31    Data Analyst                           Stage - Data Analyst F/H
# 34    Data Analyst  Data Analyst als Marketing Manager Automation ...
#
#                     job_location                          job_via  \
# 1   Guadalajara, Jalisco, Mexico                 via BeBee México
# 12                  Lyon, France                     via Jobijoba
# 18                Warsaw, Poland            via Praca Trabajo.org
# 31                 Paris, France                     via LinkedIn
# 34             Erlangen, Germany  via Central Illinois Proud Jobs
#
#            job_schedule_type  job_work_from_home search_location  \
# 1                  Full-time               False          Mexico
# ...

# %%
df_explode = df.explode('job_skills')
df_explode.head()
# Out:
#   job_title_short     job_title                  job_location  \
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
#
#             job_via job_schedule_type  job_work_from_home search_location  \
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
#
#       job_posted_date  job_no_degree_mention  job_health_insurance  \
# 1 2023-01-14 13:18:07                  False                 False
# ...

# %%
skill_stats = df_explode.groupby('job_skills').agg(
    skill_count = ('job_skills', 'count'),
    median_salary = ('salary_year_avg', 'median')
)

skill_stats
# Out:
#             skill_count  median_salary
# job_skills
# airflow            2002       111175.0
# airtable             88        90000.0
# alteryx            4570       105000.0
# angular             376       109101.0
# angular.js            2            NaN
# ...                 ...            ...
# wrike                39        75000.0
# wsl                  16            NaN
# xamarin               2            NaN
# yarn                 76        99150.0
# zoom                465        81167.0
#
# [235 rows x 2 columns]

# %%
skill_stats = skill_stats.sort_values(by='skill_count', ascending=False).head(10)

skill_stats
# Out:
#             skill_count  median_salary
# job_skills
# sql               92428        92500.0
# excel             66860        84479.0
# python            57190        98500.0
# tableau           46455        95000.0
# power bi          39380        90000.0
# r                 29996        92527.5
# sas               27998        90000.0
# powerpoint        13822        85000.0
# word              13562        80000.0
# sap               11280        90000.0

# %%
skill_stats.plot(kind='scatter', x='skill_count', y='median_salary')
plt.xlabel('Count of job Postings')
plt.ylabel('Median Yearly Salary ($USD)')
plt.title("Salary vs. Count of Job Posting for Top 10 Skills")
for i, txt in enumerate(skill_stats.index):
    plt.text(skill_stats['skill_count'].iloc[i], skill_stats['median_salary'].iloc[i], txt)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Practise Question

# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df = df[df['job_title_short'] == 'Data Scientist']

df.head()
# Out:
#    job_title_short                                          job_title  \
# 9   Data Scientist                                  Data Scientist II
# 17  Data Scientist                             Data Science Team Lead
# 19  Data Scientist                                     Data Scientist
# 20  Data Scientist                                     Data Scientist
# 21  Data Scientist  Stage - data scientist – génération ia de donn...
#
#                   job_location  \
# 9                     Anywhere
# 17                  Laurel, MD
# 19    Pune, Maharashtra, India
# 20           Zaventem, Belgium
# 21  Asnières-sur-Seine, France
#
#                                               job_via job_schedule_type  \
# 9                                    via ZipRecruiter         Full-time
# 17  via APL Careers - Johns Hopkins University App...         Full-time
# 19                                         via Indeed         Full-time
# ...

# %%
# Median Yearly Salary vs. Job Count

df_explode = df.explode('job_skills')

df_explode
# Out:
#        job_title_short           job_title job_location               job_via  \
# 9       Data Scientist   Data Scientist II     Anywhere      via ZipRecruiter
# 9       Data Scientist   Data Scientist II     Anywhere      via ZipRecruiter
# 9       Data Scientist   Data Scientist II     Anywhere      via ZipRecruiter
# 9       Data Scientist   Data Scientist II     Anywhere      via ZipRecruiter
# 9       Data Scientist   Data Scientist II     Anywhere      via ZipRecruiter
# ...                ...                 ...          ...                   ...
# 785725  Data Scientist  Analytics Engineer       Jerman  melalui Startup Jobs
# 785725  Data Scientist  Analytics Engineer       Jerman  melalui Startup Jobs
# 785725  Data Scientist  Analytics Engineer       Jerman  melalui Startup Jobs
# 785725  Data Scientist  Analytics Engineer       Jerman  melalui Startup Jobs
# 785725  Data Scientist  Analytics Engineer       Jerman  melalui Startup Jobs
#
# ...

# %%
skill_stats = df_explode.groupby('job_skills').agg(
    skill_count=('job_skills', 'count'),
    median_salary=('salary_year_avg', 'median')
)

skill_stats
# Out:
#             skill_count  median_salary
# job_skills
# airflow            3915       157000.0
# airtable             65       215500.0
# alteryx            2068       115000.0
# angular             736        93500.0
# angular.js           12            NaN
# ...                 ...            ...
# wrike                 8            NaN
# wsl                  31            NaN
# xamarin               5            NaN
# yarn                249       130000.0
# zoom                361       161250.0
#
# [237 rows x 2 columns]

# %%
skill_stats = skill_stats.sort_values(by='skill_count', ascending=False).head(10)

skill_stats
# Out:
#             skill_count  median_salary
# job_skills
# python           113711       130500.0
# sql               78982       132500.0
# r                 59566       125000.0
# sas               29534       119000.0
# tableau           29445       125000.0
# aws               26256       132500.0
# spark             24286       135000.0
# azure             21664       127500.0
# tensorflow        19153       140000.0
# excel             17545       117500.0

# %%
skill_stats.plot(kind='scatter', x='skill_count', y='median_salary')
plt.title("Salary vs. Count for Top 10 Skills of Data Scientist", fontsize=15)
plt.xlabel("Count of Job Postings")
plt.ylabel("Median Yearly Salary ($USD)")
for i, label in enumerate(skill_stats.index):
    plt.text(skill_stats['skill_count'].iloc[i], skill_stats['median_salary'].iloc[i], label)
plt.tight_layout()
plt.show()

# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
# Top 7 Countries by Median Yearly Salary vs Job Count
df = df[df['job_title_short'] == 'Data Analyst']
df.head()
# Out:
#    job_title_short                                          job_title  \
# 1     Data Analyst                                       Data Analyst
# 12    Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18    Data Analyst                                       Data Analyst
# 31    Data Analyst                           Stage - Data Analyst F/H
# 34    Data Analyst  Data Analyst als Marketing Manager Automation ...
#
#                     job_location                          job_via  \
# 1   Guadalajara, Jalisco, Mexico                 via BeBee México
# 12                  Lyon, France                     via Jobijoba
# 18                Warsaw, Poland            via Praca Trabajo.org
# 31                 Paris, France                     via LinkedIn
# 34             Erlangen, Germany  via Central Illinois Proud Jobs
#
#            job_schedule_type  job_work_from_home search_location  \
# 1                  Full-time               False          Mexico
# ...

# %%
df_explode = df.explode('job_skills')
df_explode.head()
# Out:
#   job_title_short     job_title                  job_location  \
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
# 1    Data Analyst  Data Analyst  Guadalajara, Jalisco, Mexico
#
#             job_via job_schedule_type  job_work_from_home search_location  \
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
# 1  via BeBee México         Full-time               False          Mexico
#
#       job_posted_date  job_no_degree_mention  job_health_insurance  \
# 1 2023-01-14 13:18:07                  False                 False
# ...

# %%
job_country_count = df_explode.groupby('job_country').agg(
    median_salary = ('salary_year_avg', 'median'),
    job_count = ('job_country', 'size')
)

job_country_count = job_country_count.sort_values(by='job_count', ascending=False).head(7)
job_country_count
# Out:
#                 median_salary  job_count
# job_country
# United States         90000.0     254289
# France                89100.0      45238
# United Kingdom        89100.0      29825
# Singapore            100500.0      24822
# India                102500.0      23525
# Germany              105650.0      20418
# Spain                 98500.0      18701

# %%
job_country_count.plot(kind='scatter', x='job_count', y='median_salary')
for i, label in enumerate(job_country_count.index):
    plt.text(job_country_count['job_count'].iloc[i], job_country_count['median_salary'].iloc[i], label)
plt.title("Median Salary vs. Count of Data Analyst Job Posting in Top 7 Countries")
plt.xlabel("Count of Job Posting ")
plt.ylabel("Median Yearly Salary ($USD)")
plt.tight_layout()
plt.show()

# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_copy = df.copy()
df_copy.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
# df_explode = df_copy.explode('job_skills')
# df_explode

# %%
salary_and_job_count = df_copy.groupby(['job_title_short', 'job_schedule_type']).agg(
    average_salary = ('salary_year_avg', 'mean'),
    job_count = ('job_posted_date', 'size')
)

salary_and_job_count
# Out:
#                                              average_salary  job_count
# job_title_short   job_schedule_type
# Business Analyst  Contractor                   87129.583333       1693
#                   Contractor and Internship             NaN          6
#                   Contractor and Per diem               NaN          1
#                   Contractor and Temp work     75000.000000        100
#                   Full-time                    91493.343885      44106
# ...                                                     ...        ...
# Software Engineer Per diem                              NaN          1
#                   Temp work                             NaN        120
#                   Temp work and Full-time               NaN          1
#                   Temp work and Internship              NaN          4
#                   Volunteer                             NaN          1
#
# [263 rows x 2 columns]

# %%
df_salary_and_job_count = salary_and_job_count.reset_index()

df_salary_and_job_count.sort_values(by='job_count', ascending=False, inplace=True)

df_salary_and_job_count
# Out:
#                job_title_short                     job_schedule_type  \
# 56                Data Analyst                             Full-time
# 94               Data Engineer                             Full-time
# 127             Data Scientist                             Full-time
# 4             Business Analyst                             Full-time
# 239          Software Engineer                             Full-time
# ..                         ...                                   ...
# 174  Machine Learning Engineer               Part-time and Full-time
# 41              Cloud Engineer  Full-time, Part-time, and Internship
# 173  Machine Learning Engineer              Part-time and Contractor
# 229      Senior Data Scientist                            Kontraktor
# 262          Software Engineer                             Volunteer
#
#      average_salary  job_count
# 56     94343.002423     168975
# 94    129704.718197     165225
# 127   136760.215926     153278
# ...

# %%
target_job_titles = ['Data Analyst', 'Data Scientist', 'Data Engineer']

fig, ax = plt.subplots(3, 1, figsize=(12, 8))

for i, job_title in enumerate(target_job_titles):
    df_plot = df_salary_and_job_count[df_salary_and_job_count['job_title_short'] == job_title].head(5)
    df_plot.plot(kind='scatter', x='job_count', y='average_salary', title=f"Average Salary vs. Job Count for {job_title}" , ax=ax[i], color='red')
    for j, label in enumerate(df_plot['job_schedule_type']):
        ax[i].text(df_plot['job_count'].iloc[j], df_plot['average_salary'].iloc[j], label)
    ax[i].set_xlim(0, 180000)
    ax[i].set_xlabel("")
    ax[i].set_ylabel("Average Yearly Salary")
    
fig.tight_layout()
plt.show()
fig.savefig("Scatter Plot of Average Salary and Job Count of Job List")
