# %% [markdown]
# # Exercise - Investigate Trending Skills

# %%
# Importing Library
from datasets import load_dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ast

# Loading datasets
dataset = load_dataset("lukebarousse/data_jobs")
df = dataset['train'].to_pandas()

# Clean the datasets
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_DA = df[df['job_title_short'] == 'Data Analyst'].copy()

df_DA.head()
# Out:
#    job_title_short                                          job_title  \
# 1     Data Analyst                                       Data Analyst
# 12    Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18    Data Analyst                                       Data Analyst
# 31    Data Analyst                           Stage - Data Analyst F/H
# 34    Data Analyst  Data Analyst als Marketing Manager Automation ...
#
#                     job_location                          job_via  \
# 1   Guadalajara, Jalisco, Mexico                 via BeBee México
# 12                  Lyon, France                     via Jobijoba
# 18                Warsaw, Poland            via Praca Trabajo.org
# 31                 Paris, France                     via LinkedIn
# 34             Erlangen, Germany  via Central Illinois Proud Jobs
#
#            job_schedule_type  job_work_from_home search_location  \
# 1                  Full-time               False          Mexico
# ...

# %%
# Creating a new column called "job_osted_month" in the new dataframe "df_DA". 
df_DA['job_posted_month'] = df_DA['job_posted_date'].dt.month

# Check the newly created column.
df_DA.head()
# Out:
#    job_title_short                                          job_title  \
# 1     Data Analyst                                       Data Analyst
# 12    Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18    Data Analyst                                       Data Analyst
# 31    Data Analyst                           Stage - Data Analyst F/H
# 34    Data Analyst  Data Analyst als Marketing Manager Automation ...
#
#                     job_location                          job_via  \
# 1   Guadalajara, Jalisco, Mexico                 via BeBee México
# 12                  Lyon, France                     via Jobijoba
# 18                Warsaw, Poland            via Praca Trabajo.org
# 31                 Paris, France                     via LinkedIn
# 34             Erlangen, Germany  via Central Illinois Proud Jobs
#
#            job_schedule_type  job_work_from_home search_location  \
# 1                  Full-time               False          Mexico
# ...

# %%
# Now, we explode the datafrane.
df_DA_explode = df_DA.explode('job_skills')

df_DA_explode
# Out:
#        job_title_short                           job_title  \
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# 1         Data Analyst                        Data Analyst
# ...                ...                                 ...
# 785717    Data Analyst  Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
# 785737    Data Analyst                    CRM Data Analyst
#
#                         job_location                    job_via  \
# 1       Guadalajara, Jalisco, Mexico           via BeBee México
# 1       Guadalajara, Jalisco, Mexico           via BeBee México
# ...

# %%
# now, we pivoted the dataframe with job_posred-Month as an Index and job_skills as a column.
df_DA_pivot = df_DA_explode.pivot_table(index='job_posted_month', columns='job_skills', aggfunc='size', fill_value=0)

df_DA_pivot
# Out:
# job_skills        airflow  airtable  alteryx  angular  angular.js  ansible  \
# job_posted_month
# 1                     197        17      551       63           2       20
# 2                     169         2      448       49           0       14
# 3                     181         4      442       34           0       23
# 4                     155         4      413       22           0       11
# 5                     128         8      310       30           0       19
# 6                     164        14      393       29           0       14
# 7                     207         4      366       15           0        8
# 8                     197         3      413       21           0       12
# 9                     118         4      317       21           0       14
# 10                    173        11      350       40           0       19
# 11                    169         7      293       24           0       19
# ...

# %%
# Now, we create a row"Total" in the table
df_DA_pivot.loc['Total'] = df_DA_pivot.sum()

df_DA_pivot
# Out:
# job_skills        airflow  airtable  alteryx  angular  angular.js  ansible  \
# job_posted_month
# 1                     197        17      551       63           2       20
# 2                     169         2      448       49           0       14
# 3                     181         4      442       34           0       23
# 4                     155         4      413       22           0       11
# 5                     128         8      310       30           0       19
# 6                     164        14      393       29           0       14
# 7                     207         4      366       15           0        8
# 8                     197         3      413       21           0       12
# 9                     118         4      317       21           0       14
# 10                    173        11      350       40           0       19
# 11                    169         7      293       24           0       19
# ...

# %%
# Now, we sort the values using the newly created row 'Total'.
df_DA_pivot.loc['Total'].sort_values(ascending=False).index

# Now. sort the column by this
df_DA_pivot = df_DA_pivot[df_DA_pivot.loc['Total'].sort_values(ascending=False).index]

df_DA_pivot
# Out:
# job_skills          sql  excel  python  tableau  power bi      r    sas  \
# job_posted_month
# 1                 11336   8170    6606     5596      4285   3607   3830
# 2                  7947   5772    4751     3936      3307   2576   2634
# 3                  7868   5675    4741     4051      3176   2650   2554
# 4                  7553   5496    4557     3776      3106   2399   2598
# 5                  6617   4773    4070     3245      2695   2093   1940
# 6                  7584   5724    4707     3812      3275   2442   2174
# 7                  7687   5513    4831     3928      3350   2444   2118
# 8                  8823   6482    5576     4533      3859   2975   2560
# 9                  6829   4886    4229     3446      3118   2146   1880
# 10                 7474   5217    4693     3709      3340   2380   2114
# 11                 6652   4776    4233     3284      3012   2159   1738
# 12                 6058   4376    4196     3139      2857   2125   1858
# ...

# %%
# Now, Drop the total row
df_DA_pivot = df_DA_pivot.drop('Total')

df_DA_pivot
# Out:
# job_skills          sql  excel  python  tableau  power bi     r   sas  \
# job_posted_month
# 1                 11336   8170    6606     5596      4285  3607  3830
# 2                  7947   5772    4751     3936      3307  2576  2634
# 3                  7868   5675    4741     4051      3176  2650  2554
# 4                  7553   5496    4557     3776      3106  2399  2598
# 5                  6617   4773    4070     3245      2695  2093  1940
# 6                  7584   5724    4707     3812      3275  2442  2174
# 7                  7687   5513    4831     3928      3350  2444  2118
# 8                  8823   6482    5576     4533      3859  2975  2560
# 9                  6829   4886    4229     3446      3118  2146  1880
# 10                 7474   5217    4693     3709      3340  2380  2114
# 11                 6652   4776    4233     3284      3012  2159  1738
# 12                 6058   4376    4196     3139      2857  2125  1858
#
# ...

# %%
# Nor we get only first five columns of the pivot table an d plot it.
df_DA_pivot.iloc[: , :5].plot(kind='line')
plt.title('Top 5 Skills for Data Analyst per month')
plt.ylabel('Count ->')
plt.xlabel('')
plt.show()

# %%
df_DA_pivot = df_DA_pivot.reset_index()
df_DA_pivot['job_posted_month_name'] = df_DA_pivot['job_posted_month'].apply(lambda x: pd.to_datetime(x, format='%m').strftime('%b'))

df_DA_pivot
# Out:
# job_skills  level_0  index  job_posted_month    sql  excel  python  tableau  \
# 0                 0      0                 1  11336   8170    6606     5596
# 1                 1      1                 2   7947   5772    4751     3936
# 2                 2      2                 3   7868   5675    4741     4051
# 3                 3      3                 4   7553   5496    4557     3776
# 4                 4      4                 5   6617   4773    4070     3245
# 5                 5      5                 6   7584   5724    4707     3812
# 6                 6      6                 7   7687   5513    4831     3928
# 7                 7      7                 8   8823   6482    5576     4533
# 8                 8      8                 9   6829   4886    4229     3446
# 9                 9      9                10   7474   5217    4693     3709
# 10               10     10                11   6652   4776    4233     3284
# ...

# %%
# Set the column "Job_posted_month_name" to index
df_DA_pivot = df_DA_pivot.set_index('job_posted_month_name')

df_DA_pivot
# Out:
# job_skills             level_0  index  job_posted_month    sql  excel  python  \
# job_posted_month_name
# Jan                          0      0                 1  11336   8170    6606
# Feb                          1      1                 2   7947   5772    4751
# Mar                          2      2                 3   7868   5675    4741
# Apr                          3      3                 4   7553   5496    4557
# May                          4      4                 5   6617   4773    4070
# Jun                          5      5                 6   7584   5724    4707
# Jul                          6      6                 7   7687   5513    4831
# Aug                          7      7                 8   8823   6482    5576
# Sep                          8      8                 9   6829   4886    4229
# Oct                          9      9                10   7474   5217    4693
# Nov                         10     10                11   6652   4776    4233
# ...

# %%
# Now, we drop the columns
df_DA_pivot = df_DA_pivot.drop(columns='job_posted_month')
df_DA_pivot = df_DA_pivot.drop(columns='index')
df_DA_pivot = df_DA_pivot.drop(columns='level_0')

df_DA_pivot
# Out:
# job_skills               sql  excel  python  tableau  power bi     r   sas  \
# job_posted_month_name
# Jan                    11336   8170    6606     5596      4285  3607  3830
# Feb                     7947   5772    4751     3936      3307  2576  2634
# Mar                     7868   5675    4741     4051      3176  2650  2554
# Apr                     7553   5496    4557     3776      3106  2399  2598
# May                     6617   4773    4070     3245      2695  2093  1940
# Jun                     7584   5724    4707     3812      3275  2442  2174
# Jul                     7687   5513    4831     3928      3350  2444  2118
# Aug                     8823   6482    5576     4533      3859  2975  2560
# Sep                     6829   4886    4229     3446      3118  2146  1880
# Oct                     7474   5217    4693     3709      3340  2380  2114
# Nov                     6652   4776    4233     3284      3012  2159  1738
# ...

# %%
# Now we get only first five columns of the pivot table an d plot it.
df_DA_pivot.iloc[: , :5].plot(kind='line')
plt.title('Top 5 Skills for Data Analyst per month')
plt.ylabel('Count ->')
plt.xlabel('')
plt.show()
