# %%
# Importing Library
from datasets import load_dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Loading Dataset
dataset = load_dataset("lukebarousse/data_jobs")
df = dataset['train'].to_pandas()

# dataset Cleaning
df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

# %%
df_salary = df[pd.notna(df['salary_year_avg'])].copy()

# %%
help(df.apply)
# Out:
# Help on method apply in module pandas.core.frame:
#
# apply(func: 'AggFuncType', axis: 'Axis' = 0, raw: 'bool' = False, result_type: "Literal['expand', 'reduce', 'broadcast'] | None" = None, args=(), by_row: "Literal[False, 'compat']" = 'compat', engine: "Literal['python', 'numba']" = 'python', engine_kwargs: 'dict[str, bool] | None' = None, **kwargs) method of pandas.core.frame.DataFrame instance
#     Apply a function along an axis of the DataFrame.
#
#     Objects passed to the function are Series objects whose index is
#     either the DataFrame's index (``axis=0``) or the DataFrame's columns
#     (``axis=1``). By default (``result_type=None``), the final return type
#     is inferred from the return type of the applied function. Otherwise,
#     it depends on the `result_type` argument.
#
#     Parameters
#     ----------
#     func : function
#         Function to apply to each column or row.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
# ...

# %%
# Create a projected salary function
def projected_salary(salary):
    return salary * 1.03

df_salary['salary_year_inflated'] = df_salary['salary_year_avg'].apply(projected_salary)

df_salary[['salary_year_avg', 'salary_year_inflated']].head(20)
# Out:
#      salary_year_avg  salary_year_inflated
# 28          109500.0             112785.00
# 77          140000.0             144200.00
# 92          120000.0             123600.00
# 100         228222.0             235068.66
# 109          89000.0              91670.00
# 116         114000.0             117420.00
# 146         129500.0             133385.00
# 180          90250.0              92957.50
# 212         157500.0             162225.00
# 257         103128.0             106221.84
# 307         185000.0             190550.00
# 339         195000.0             200850.00
# 380          97500.0             100425.00
# 388          89000.0              91670.00
# 410         133285.0             137283.55
# 450         157500.0             162225.00
# 495         168500.0             173555.00
# 520          63000.0              64890.00
# 545          80000.0              82400.00
# 571         110000.0             113300.00

# %%
df_salary['salary_year_inflated'] = df_salary['salary_year_avg'].apply(lambda salary: salary * 1.03)

df_salary[['salary_year_avg', 'salary_year_inflated']]
# Out:
#         salary_year_avg  salary_year_inflated
# 28             109500.0             112785.00
# 77             140000.0             144200.00
# 92             120000.0             123600.00
# 100            228222.0             235068.66
# 109             89000.0              91670.00
# ...                 ...                   ...
# 785624         139216.0             143392.48
# 785641         150000.0             154500.00
# 785648         221875.0             228531.25
# 785682         157500.0             162225.00
# 785692         157500.0             162225.00
#
# [22003 rows x 2 columns]

# %%
df['salary_year_inflated'] = df_salary.salary_year_avg * 1.03

df_salary[['salary_year_avg', 'salary_year_inflated']]
# Out:
#         salary_year_avg  salary_year_inflated
# 28             109500.0             112785.00
# 77             140000.0             144200.00
# 92             120000.0             123600.00
# 100            228222.0             235068.66
# 109             89000.0              91670.00
# ...                 ...                   ...
# 785624         139216.0             143392.48
# 785641         150000.0             154500.00
# 785648         221875.0             228531.25
# 785682         157500.0             162225.00
# 785692         157500.0             162225.00
#
# [22003 rows x 2 columns]

# %%
df['job_skills'][1]
# Out:
# "['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']"

# %%
type(df.job_skills[1])
# Out:
# str

# %%
import ast

ast.literal_eval(df.job_skills[1])
# Out:
# ['r', 'python', 'sql', 'nosql', 'power bi', 'tableau']

# %%
df['job_skills'] = ast.literal_eval(df['job_skills'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 df['job_skills'] = ast.literal_eval(df['job_skills'])
#
# File c:\Users\gaura\anaconda3\envs\python_course\Lib\ast.py:110, in literal_eval(node_or_string)
#     108                 return left - right
#     109     return _convert_signed_num(node)
# --> 110 return _convert(node_or_string)
#
# File c:\Users\gaura\anaconda3\envs\python_course\Lib\ast.py:109, in literal_eval.<locals>._convert(node)
#     107         else:
#     108             return left - right
# --> 109 return _convert_signed_num(node)
#
# File c:\Users\gaura\anaconda3\envs\python_course\Lib\ast.py:83, in literal_eval.<locals>._convert_signed_num(node)
#      81     else:
#      82         return - operand
# ---> 83 return _convert_num(node)
#
# ...

# %%
df[pd.isna(df['job_skills'])]
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 21            Data Scientist
# 26             Data Engineer
# 29            Data Scientist
# 36              Data Analyst
# ...                      ...
# 785713        Cloud Engineer
# 785715          Data Analyst
# 785718      Business Analyst
# 785724         Data Engineer
# 785729         Data Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 21      Stage - data scientist – génération ia de donn...
# 26                                          Data Engineer
# 29                                         Data Scientist
# 36                                           Data Analyst
# ...                                                   ...
# 785713  Data Center Chief Engineer, AWS Infrastructure...
# 785715  Amul Careers 2023 - Apply Online - Data Analys...
# 785718                      Senior Performance QA Analyst
# ...

# %%
# Creating a function called "clean_list".
# Here we using the "Function" for this.
def clean_list(skill_list):
    if pd.notna(skill_list):
        return ast.literal_eval(skill_list)
    
df['job_skills'] = df.job_skills.apply(clean_list)

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
# Now, we do the same thing by the "lambda" Function.
df['job_skills'] = df['job_skills'].apply(lambda skill_list: ast.literal_eval(skill_list) if pd.notna(skill_list) else skill_list)

df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[104], line 2
#       1 # Now, we do the same thing by the "lambda" Function.
# ----> 2 df['job_skills'] = df['job_skills'].apply(lambda skill_list: ast.literal_eval(skill_list) if pd.notna(skill_list) else skill_list)
#       4 df.head()
#
# File c:\Users\gaura\anaconda3\envs\python_course\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
# ...

# %%
# Confirming the conversion from str to list of the column 'job_skills'.
type(df.job_skills[1])
# Out:
# list

# %% [markdown]
# # Calculate projected salary next year
#
# - Senior role assume 5%
# - Other role assume 3%

# %%
def projected_salary(row):
    if "Senior" in row['job_title_short']:
        return 1.05 * row['salary_year_avg']
    else:
        return 1.03 * row['salary_year_avg']



df_salary['salary_year_inflated'] = df_salary.apply(projected_salary, axis=1)

df_salary[['job_title_short', 'salary_year_avg', 'salary_year_inflated']]
# Out:
#        job_title_short  salary_year_avg  salary_year_inflated
# 28      Data Scientist         109500.0             112785.00
# 77       Data Engineer         140000.0             144200.00
# 92       Data Engineer         120000.0             123600.00
# 100     Data Scientist         228222.0             235068.66
# 109       Data Analyst          89000.0              91670.00
# ...                ...              ...                   ...
# 785624   Data Engineer         139216.0             143392.48
# 785641   Data Engineer         150000.0             154500.00
# 785648  Data Scientist         221875.0             228531.25
# 785682  Data Scientist         157500.0             162225.00
# 785692  Data Scientist         157500.0             162225.00
#
# [22003 rows x 3 columns]

# %%
df_salary['salary_year_projected'] = df_salary.apply(lambda row: 1.05 * row['salary_year_avg'] if "Senior" in row['job_title_short'] else 1.03 * row['salary_year_avg'], axis=1)

df_salary[['job_title_short', 'salary_year_avg', 'salary_year_inflated']]
# Out:
#        job_title_short  salary_year_avg  salary_year_inflated
# 28      Data Scientist         109500.0             112785.00
# 77       Data Engineer         140000.0             144200.00
# 92       Data Engineer         120000.0             123600.00
# 100     Data Scientist         228222.0             235068.66
# 109       Data Analyst          89000.0              91670.00
# ...                ...              ...                   ...
# 785624   Data Engineer         139216.0             143392.48
# 785641   Data Engineer         150000.0             154500.00
# 785648  Data Scientist         221875.0             228531.25
# 785682  Data Scientist         157500.0             162225.00
# 785692  Data Scientist         157500.0             162225.00
#
# [22003 rows x 3 columns]

# %% [markdown]
# # AI Generated Problems

# %%
# Importing library
import pandas as pd

# Sample DataFrame
data = {
    'job_title_short': ['Data Scientist', 'Senior Data Scientist', 'Data Engineer', 'Senior Data Engineer', 'Data Analyst'],
    'salary_year_avg': [90000, 120000, 100000, 130000, 80000]
}

# Convert the dictionery to dataframe
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#          job_title_short  salary_year_avg
# 0         Data Scientist            90000
# 1  Senior Data Scientist           120000
# 2          Data Engineer           100000
# 3   Senior Data Engineer           130000
# 4           Data Analyst            80000

# %%
# Define the function to calculate the projected salary
def projected_salary(row):
    if 'Senior' in row['job_title_short']:
        return 1.10 * row['salary_year_avg']
    else:
        return 1.05 * row['salary_year_avg']

# Apply the function to create the new column
df['salary_year_inflated'] = df.apply(projected_salary, axis=1)

# Display the updated DataFrame
df
# Out:
#          job_title_short  salary_year_avg  salary_year_inflated
# 0         Data Scientist            90000               94500.0
# 1  Senior Data Scientist           120000              132000.0
# 2          Data Engineer           100000              105000.0
# 3   Senior Data Engineer           130000              143000.0
# 4           Data Analyst            80000               84000.0

# %%
df['salary_year_inflated'] = df.apply(lambda row: 1.10 * row['salary_year_avg'] if "Senior" in row['job_title_short'] else 1.05 * row['salary_year_avg'], axis=1)

df
# Out:
#          job_title_short  salary_year_avg  salary_year_inflated
# 0         Data Scientist            90000               94500.0
# 1  Senior Data Scientist           120000              132000.0
# 2          Data Engineer           100000              105000.0
# 3   Senior Data Engineer           130000              143000.0
# 4           Data Analyst            80000               84000.0

# %% [markdown]
# ## Problem: 2

# %%
import pandas as pd

data = {
    'job_title' : ['Data Scientist', 'Data Engineer', 'Data Analyst'],
    'salary_year_avg' : [100000, 120000, 110000]
}

# %%
# Convert this dict to datatype
df = pd.DataFrame(data)

# %%
def inflation(salary):
    return 1.10 * salary

df['salary_year_inflated'] = df['salary_year_avg'].apply(inflation)

df
# Out:
#         job_title  salary_year_avg  salary_year_inflated
# 0  Data Scientist           100000              110000.0
# 1   Data Engineer           120000              132000.0
# 2    Data Analyst           110000              121000.0

# %%
df['salary_year_inflated'] = df['salary_year_avg'].apply(lambda salary: salary * 1.10)

df
# Out:
#         job_title  salary_year_avg  salary_year_inflated
# 0  Data Scientist           100000              110000.0
# 1   Data Engineer           120000              132000.0
# 2    Data Analyst           110000              121000.0
