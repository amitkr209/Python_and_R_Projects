# %%
# Importing Library
from datasets import load_dataset
import numpy as np
import  pandas as pd
import matplotlib.pyplot as plt
import ast

# Loading Datasets
dataset = load_dataset("lukebarousse/data_jobs")
df = dataset['train'].to_pandas()

# Data Cleaning
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
# Only get the data analyst jobs in united stataes.
df_DA_US = df[(df['job_title'] == 'Data Analyst') & (df['job_country'] == 'United States')].copy()

df_DA_US.head()
# Out:
#     job_title_short     job_title    job_location          job_via  \
# 36     Data Analyst  Data Analyst  Des Moines, IA  via Trabajo.org
# 155    Data Analyst  Data Analyst       Tampa, FL     via LinkedIn
# 332    Data Analyst  Data Analyst   Mossville, IL  via Trabajo.org
# 385    Data Analyst  Data Analyst    Waukesha, WI  via Trabajo.org
# 476    Data Analyst  Data Analyst   St Peters, MO  via Trabajo.org
#
#     job_schedule_type  job_work_from_home          search_location  \
# 36          Full-time               False  Illinois, United States
# 155         Full-time               False   Florida, United States
# 332         Full-time               False  Illinois, United States
# 385         Full-time               False  Illinois, United States
# 476         Full-time               False  Illinois, United States
#
#         job_posted_date  job_no_degree_mention  job_health_insurance  \
# 36  2023-11-06 13:01:22                  False                  True
# ...

# %%
df_DA_US['salary_year_avg'].plot(kind='hist',
                                bins=50, 
                                edgecolor='black')
plt.xlim(0, 250_000)

ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f"${int(x/1000)}K"))

plt.title("Distribution of United States Data Analyst Yearly Salary")
plt.xlabel("Yearly Salary")
plt.ylabel("Number of Jobs")
plt.show()

# %%
job_titles = ['Data Analyst', 'Data Engineer', 'Data Scientist']

df_DA_IND = df[(df['job_title_short'].isin (job_titles)) & (df['job_country'] == 'India')]

df_DA_IND.head()
# Out:
#    job_title_short                                          job_title  \
# 16   Data Engineer                                  Big Data Engineer
# 19  Data Scientist                                     Data Scientist
# 29  Data Scientist                                     Data Scientist
# 38    Data Analyst              Data Quality and Governance Analyst 1
# 80   Data Engineer  Director - Enterprise Architecture and Data En...
#
#                   job_location          job_via job_schedule_type  \
# 16    Pune, Maharashtra, India     via LinkedIn         Full-time
# 19    Pune, Maharashtra, India       via Indeed         Full-time
# 29    Pune, Maharashtra, India       via Exusia         Full-time
# 38                       India  via Trabajo.org         Full-time
# 80  Chennai, Tamil Nadu, India       via Indeed         Full-time
#
#     job_work_from_home search_location     job_posted_date  \
# 16               False           India 2023-06-15 13:28:03
# ...

# %%
df_DA_IND = df_DA_IND.dropna(subset='salary_year_avg')

df_DA_IND.head()
# Out:
#      job_title_short                                          job_title  \
# 2022   Data Engineer                     Data Engineer - SQL (Power BI)
# 2785   Data Engineer  Staff Software Engineer - Data Engineering (Ja...
# 3930  Data Scientist                                Lead Data Scientist
# 7946   Data Engineer                           Data Engineering Manager
# 9143  Data Scientist                             Manager - Data Science
#
#                      job_location          job_via job_schedule_type  \
# 2022                        India  via Ai-Jobs.net         Full-time
# 2785  Bengaluru, Karnataka, India  via Ai-Jobs.net         Full-time
# 3930  Bengaluru, Karnataka, India  via Ai-Jobs.net         Full-time
# 7946     Mysuru, Karnataka, India  via Ai-Jobs.net         Full-time
# 9143  Bengaluru, Karnataka, India  via Ai-Jobs.net         Full-time
#
#       job_work_from_home search_location     job_posted_date  \
# ...

# %%
df_DA_IND['salary_year_avg'].plot(kind='hist', bins=40, edgecolor='black')
plt.xlim(0, 300_000)

ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f"${int(x/1000)}K"))

plt.title("Distribution of India's Data Science Jobs Yearly Salary in USD($)")
plt.xlabel("Yearly Salary")
plt.ylabel("Number of Jobs")
plt.show()

# %% [markdown]
# # Practise Questions

# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
# Data Scientist Hourly Salaries

df_DS = df[df['job_title_short'] == 'Data Scientist']

df_DS.head()
# Out:
#    job_title_short                                          job_title  \
# 9   Data Scientist                                  Data Scientist II
# 17  Data Scientist                             Data Science Team Lead
# 19  Data Scientist                                     Data Scientist
# 20  Data Scientist                                     Data Scientist
# 21  Data Scientist  Stage - data scientist – génération ia de donn...
#
#                   job_location  \
# 9                     Anywhere
# 17                  Laurel, MD
# 19    Pune, Maharashtra, India
# 20           Zaventem, Belgium
# 21  Asnières-sur-Seine, France
#
#                                               job_via job_schedule_type  \
# 9                                    via ZipRecruiter         Full-time
# 17  via APL Careers - Johns Hopkins University App...         Full-time
# 19                                         via Indeed         Full-time
# ...

# %%
df_DS = df_DS.dropna(subset='salary_hour_avg')
df_DS
# Out:
#        job_title_short                                          job_title  \
# 448     Data Scientist  Jnr Data Scientist for exciting projects with ...
# 734     Data Scientist  Data Scientist - NLP, regex, OpenCV, Python, A...
# 881     Data Scientist  Data Scientist with expertise in deep learning...
# 1100    Data Scientist                         Data Scientist - R, Python
# 1382    Data Scientist                                     Data Scientist
# ...                ...                                                ...
# 783522  Data Scientist                                     Data Scientist
# 783753  Data Scientist           Data Scientist 3 - Full-time / Part-time
# 783976  Data Scientist                  Data Scientist - Contract to Hire
# 785476  Data Scientist                               Data Scientist, Lead
# 785492  Data Scientist                                     Data Scientist
#
#            job_location       job_via         job_schedule_type  \
# ...

# %%
df_DS['salary_hour_avg'].plot(kind='hist', bins=20, edgecolor='black')
plt.xlim(0, 150)
plt.xlabel("Hourly Salary")
plt.ylabel("Number of Jobs")
plt.title("Distribution of Data Scientist Hourly Salary")
plt.show()

# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %% [markdown]
# # Job Postings by Number of Skills

# %%
df_copy = df.copy()

df_copy = df_copy.dropna(subset='job_skills')

df_copy['num_of_skills'] = df_copy['job_skills'].apply(lambda x: len(x) if x else 0)
df_copy
# Out:
#           job_title_short                                          job_title  \
# 1            Data Analyst                                       Data Analyst
# 2           Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3           Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4           Data Engineer                             Data Engineer- Sr Jobs
# 5           Data Engineer                                  GCP Data Engineer
# ...                   ...                                                ...
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
# ...

# %%
df_copy['num_of_skills'].plot(kind='hist', bins=30, edgecolor='black')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)
